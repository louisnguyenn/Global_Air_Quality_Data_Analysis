# %%
import pandas as pd

# reading the dataset using pandas csv reader
df = pd.read_csv("air_quality_health_dataset.csv")
display(df)
# Out:
#               city        date  aqi  pm2_5  pm10   no2    o3  temperature  \
# 0      Los Angeles  2020-01-01   65   34.0  52.7   2.2  38.5         33.5
# 1          Beijing  2020-01-02  137   33.7  31.5  36.7  27.5         -1.6
# 2           London  2020-01-03  266   43.0  59.6  30.4  57.3         36.4
# 3      Mexico City  2020-01-04  293   33.7  37.9  12.3  42.7         -1.0
# 4            Delhi  2020-01-05  493   50.3  34.8  31.2  35.6         33.5
# ...            ...         ...  ...    ...   ...   ...   ...          ...
# 88484        Tokyo  2262-04-06   22   23.4  53.4  24.3  58.9          9.1
# 88485        Delhi  2262-04-07  170   48.0  32.4  25.0  15.7          5.6
# 88486        Delhi  2262-04-08  307   46.7  21.8  31.9  45.1          9.5
# 88487      Beijing  2262-04-09   65   31.9  26.0  38.1  53.0         17.8
# 88488  Mexico City  2262-04-10   59   41.8  50.1  31.2  52.0         25.0
#
#        humidity  hospital_admissions population_density  hospital_capacity
# ...

# %%
import pandas as pd

df = pd.read_csv("air_quality_health_dataset.csv")

# displaying dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88489 entries, 0 to 88488
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 88489 non-null  object
#  1   date                 88489 non-null  object
#  2   aqi                  88489 non-null  int64
#  3   pm2_5                88489 non-null  float64
#  4   pm10                 88489 non-null  float64
#  5   no2                  88489 non-null  float64
#  6   o3                   88489 non-null  float64
#  7   temperature          88489 non-null  float64
#  8   humidity             88489 non-null  int64
#  9   hospital_admissions  88489 non-null  int64
#  10  population_density   88489 non-null  object
#  11  hospital_capacity    88489 non-null  int64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 8.1+ MB

# %%
import pandas as pd

df = pd.read_csv("air_quality_health_dataset.csv")

# displaying summary statistics
df.describe()
# Out:
#                 aqi         pm2_5          pm10           no2            o3  \
# count  88489.000000  88489.000000  88489.000000  88489.000000  88489.000000
# mean     249.370182     35.144951     50.118654     30.006211     39.978895
# std      144.479132     14.767994     19.796392      9.963139     12.007258
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      124.000000     24.900000     36.600000     23.300000     31.900000
# 50%      249.000000     35.100000     50.000000     30.000000     40.000000
# 75%      374.000000     45.200000     63.500000     36.700000     48.100000
# max      499.000000    109.900000    143.500000     71.400000     93.500000
#
#         temperature      humidity  hospital_admissions  hospital_capacity
# count  88489.000000  88489.000000         88489.000000       88489.000000
# mean      17.522962     56.950966             8.049385        1024.463165
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("air_quality_preprocessed_dataset.csv")

# boxplot
sns.boxplot(data=df, x='city', y='aqi')
plt.xticks(rotation=45)
plt.title('AQI Distribution by City')
plt.show()

# heatmap
numeric_cols = df.select_dtypes(include=['number'])
sns.heatmap(numeric_cols.corr(), annot=True, cmap='RdYlBu')
plt.title('Air Quality Correlations')
plt.show()

# distribution of AQI
sns.histplot(data=df, x='aqi', kde=True)
plt.title('AQI Distribution')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("air_quality_preprocessed_dataset.csv", encoding="utf-8-sig")

# create the matplotlib plot
plt.figure()

city_avg = df.groupby('city')['aqi'].mean().sort_values(ascending=False)

bars = plt.bar(city_avg.index, city_avg.values)

plt.title("Average Air Quality Index by City")
plt.xlabel("City")
plt.ylabel("Average AQI")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# plotting histogram with matplotlib
df.plot.hist()
plt.show()

# plotting scatter with matplotlib
df.plot.scatter('city', 'aqi')
plt.xticks(rotation=45, ha='right')
plt.show()

# plotting boxplot with matplotlib
df.boxplot('aqi')
# print(df.columns.tolist())
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("air_quality_preprocessed_dataset.csv", encoding="utf-8-sig")

# using pandas to find the min, max, and sum of the aqi in all cities
# df.min()
# df.max()
df.sum()
# Out:
# city    Los AngelesBeijingLondonMexico CityDelhiCairoL...
# aqi                                              22066518
# dtype: object

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("air_quality_preprocessed_dataset.csv", encoding="utf-8-sig")

# using numpy to find the min, max, and sum of the aqi in all cities
numeric_df = df.select_dtypes(include=[np.number])

# np.min(numeric_df, axis=0)
# np.max(numeric_df, axis=0)
np.sum(numeric_df, axis=0)
# Out:
# aqi    22066518
# dtype: int64

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("delhi_air_quality_preprocessed_dataset.csv", encoding="utf-8-sig")

# using numpy to find the min, max, and sum of the aqi with the pre-processed file with the city 'Delhi'
# aqi_min = np.min(df['aqi'])
# aqi_max = np.max(df['aqi'])
np.sum(df['aqi'])
# Out:
# np.int64(6587512)
