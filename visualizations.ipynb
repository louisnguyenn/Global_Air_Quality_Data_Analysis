# %%
import pandas as pd

# reading the dataset using pandas csv reader
df = pd.read_csv("air_quality_health_dataset.csv")
display(df)
# Out:
#               city        date  aqi  pm2_5  pm10   no2    o3  temperature  \
# 0      Los Angeles  2020-01-01   65   34.0  52.7   2.2  38.5         33.5
# 1          Beijing  2020-01-02  137   33.7  31.5  36.7  27.5         -1.6
# 2           London  2020-01-03  266   43.0  59.6  30.4  57.3         36.4
# 3      Mexico City  2020-01-04  293   33.7  37.9  12.3  42.7         -1.0
# 4            Delhi  2020-01-05  493   50.3  34.8  31.2  35.6         33.5
# ...            ...         ...  ...    ...   ...   ...   ...          ...
# 88484        Tokyo  2262-04-06   22   23.4  53.4  24.3  58.9          9.1
# 88485        Delhi  2262-04-07  170   48.0  32.4  25.0  15.7          5.6
# 88486        Delhi  2262-04-08  307   46.7  21.8  31.9  45.1          9.5
# 88487      Beijing  2262-04-09   65   31.9  26.0  38.1  53.0         17.8
# 88488  Mexico City  2262-04-10   59   41.8  50.1  31.2  52.0         25.0
#
#        humidity  hospital_admissions population_density  hospital_capacity
# 0            33                    5              Rural               1337
# 1            32                    4              Urban               1545
# 2            25                   10           Suburban               1539
# 3            67                   10              Urban                552
# 4            72                    9           Suburban               1631
# ...         ...                  ...                ...                ...
# 88484        55                    5           Suburban                419
# 88485        40                   10              Urban                695
# 88486        44                   12              Urban                245
# 88487        46                   11           Suburban               1291
# 88488        65                    8              Urban                983
#
# [88489 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# reading the dataset as a dataframe using pandas using try-except block
try: 
    df = pd.read_csv("air_quality_preprocessed_dataset.csv", encoding="utf-8-sig")

except IOError as err:
    print("Unable to open pre-processed file 'air_quality_preprocessed_dataset.csv' : {}".format(err), file=sys.stderr)
    sys.exit(1)

# using plotly to create a bar graph
plotly_fig = px.bar(df, x="City", y="AQI", title="Air Quality Metrics in Cities")
plotly_fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 16
#      13     sys.exit(1)
#      15 # using plotly to create a bar graph
# ---> 16 plotly_fig = px.bar(df, x="City", y="AQI", title="Air Quality Metrics in Cities")
#      17 plotly_fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\express\_chart_types.py:381, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, subtitle, template, width, height)
#     332 def bar(
#     333     data_frame=None,
#     334     x=None,
#    (...)    375     height=None,
#     376 ) -> go.Figure:
#     377     """
#     378     In a bar plot, each row of `data_frame` is represented as a rectangular
#     379     mark.
#     380     """
# --> 381     return make_figure(
#     382         args=locals(),
#     383         constructor=go.Bar,
#     384         trace_patch=dict(textposition="auto"),
#     385         layout_patch=dict(barmode=barmode),
#     386     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\express\_core.py:2483, in make_figure(args, constructor, trace_patch, layout_patch)
#    2480 layout_patch = layout_patch or {}
#    2481 apply_default_cascade(args)
# -> 2483 args = build_dataframe(args, constructor)
#    2484 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2485     args = process_dataframe_hierarchy(args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\express\_core.py:1729, in build_dataframe(args, constructor)
#    1726     args["color"] = None
#    1727 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1729 df_output, wide_id_vars = process_args_into_dataframe(
#    1730     args,
#    1731     wide_mode,
#    1732     var_name,
#    1733     value_name,
#    1734     is_pd_like,
#    1735     native_namespace,
#    1736 )
#    1737 df_output: nw.DataFrame
#    1738 # now that `df_output` exists and `args` contains only references, we complete
#    1739 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1740 # df_output
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\plotly\express\_core.py:1330, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1328         if argument == "index":
#    1329             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1330         raise ValueError(err_msg)
#    1331 elif length and (actual_len := len(df_input)) != length:
#    1332     raise ValueError(
#    1333         "All arguments should have the same length. "
#    1334         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)   1341         )
#    1342     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Los Angeles', '65'] but received: City
